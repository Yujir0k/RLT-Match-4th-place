# %% [markdown]
# # Model config and examples
#
# Конфигурация скоринга и примеры входного/выходного CSV из ML-пакета.

# %% [markdown]
# ## `config/model_config.json`

# %%
MODEL_CONFIG = r'''{
  "package_version": "2026-04-11",
  "model_name": "hybrid_tfidf_svd_rules_v1",
  "mode": "speed_optimized_runtime",
  "artifacts": {
    "index_dir": "artifacts/index",
    "runtime_bundle": "artifacts/runtime/runtime_bundle.pkl"
  },
  "source_data": {
    "purchases_csv": "Закупки для интенсива_20260411_csv.csv",
    "index_cache_key": "1b003bbd5534a2e9"
  },
  "scoring": {
    "top_rows": 50,
    "semantic_top_lots": 30,
    "top_lots": 3,
    "chunk_size": 32,
    "char_weight": 0.18,
    "embedding_weight": 0.22,
    "item_presence_weight": 0.58,
    "type_exact_bonus": 0.14,
    "type_compatible_bonus": 0.06,
    "type_mismatch_penalty": 0.18,
    "type_missing_keyword_penalty": 0.08,
    "overlap_bonus_weight": 0.04,
    "service_penalty": 0.12
  }
}
'''
print(MODEL_CONFIG)

# %% [markdown]
# ## Пример входного CSV

# %%
BUYER_INPUT_EXAMPLE = r'''﻿id;Категория;Наименование;Характеристики
35621604;Материалы расходные для дыроколов;Нож запасной Deli металлический для дырокола E0150 (2 штуки в упаковке);"""Диаметр:10.00000;Количество штук в упаковке:2.00000;Материал:металл;Цвет:черный, серебристый;Вид товаров:Офисные принадлежности;Высота:80"""
35325587;DJ-проигрыватели;DJ CD-проигрыватель D.A.S. HDJ-2450 MP3;"""Тип:DJ CD-проигрыватель, двойная дека;Загрузка диска:фронтальный лоток;Количество дисков:2.00000;Поддержка стандартов:MP3, CD;Коэффициент гармоник:0.01000;Отношение сигнал/шум:94;Разделение каналов:86;Входы и Выходы:линейный, коаксиальный;Тип цифро-аналогового преобразователя:однобитный;Передискретизация:8х;Блок питания:встроенный;Потребляемая мощность:17;Управление:Jog Dial;Цветовое оформление:черный;Габаритные размеры:482x176x268;Вес:7.00000"""
35325768;DJ-проигрыватели;DJ CD-проигрыватель Inter-M DC-101;"""Тип:DJ CD-проигрыватель;Загрузка диска:верхняя загрузка;Коэффициент гармоник:0.00500;Отношение сигнал/шум:105;Динамический диапазон:95;Разделение каналов:95;Полоса пропускания (+/- 0,5 дБ):20 - 20000;Входы и Выходы:линейный, оптический;Выходное напряжение:2.00000;ЦАП:Burr-Brown;Разрядность:16;Частота дискретизации:44.10000;Блок питания:встроенный;Потребляемая мощность:14;Транспорт:Sony KSM-213 CCM;Управление:Jog Dial;Габаритные размеры:315x85x355;Вес:4.50000"""
35213112;USB-накопители твердотельные (флеш-драйвы)....;Флешка ADATA DashDrive UV150;"""Интерфейс:USB 3.0;Скорость чтения данных:90;ReadyBoost:0;Защита паролем:0;Аппаратное шифрование данных:0;Сжатие данных:0;Резервное копирование данных:0;Выдвижной разъем:0;Защита от перезаписи:0;Водонепроницаемый корпус:0;Материал корпуса:пластик;Ширина:18.00000;Длина:58;Толщина:10.00000;Вид товаров:Информационно-технологический товар, средство связи, оргтехника, электроника (включая программное обеспечение);Виды товаров информационно-технологических, средств связи, оргтехники, электроники (включая программное обеспечение):Периферийное устройство;Вид периферийное устройство:Запоминающее устройство"""
1215368;Машины брошюровочные и переплетные;Переплетная машина для пластиковой пружины BRAUBERG B8, пробивает 8 л., сшивает до 125 л.;"""Привод перфорации:ручной;Макс. диаметр пружины:14;Количество пробиваемых листов:8;Тип переплета:пластиковая пружина;Отдельный размыкающий рычаг:0;Селектор формата:1;Стартовый набор расходников в комплекте:0;Тип ручки:0;Макс. кол-во переплетаемых листов:125;Селектор выбора диаметра пружины:0;Регулировка глубины перфорации:0;Отсек для хранения расходников:0;Раздельные механизмы перфорации и сшивания:0;Загрузка документов:горизонтальная;Макс. формат переплетаемого документа по длинной стороне:А4"""
'''
print(BUYER_INPUT_EXAMPLE[:3000])

# %% [markdown]
# ## Пример выходного CSV

# %%
BUYER_OUTPUT_EXAMPLE = r'''﻿seller_id,seller_category,seller_name,pn_lot,platform_brief,publish_date,platform_number,lot_number,procedure_name,lot_subject,matched_unit_name,unit_okpd_code,seller_product_type,matched_product_type,type_relation,lexical_score,semantic_score,retrieval_score,item_presence_score,text_score,overlap_bonus,type_score,has_expected_type_signal,type_missing_penalty,service_penalty,final_score,score_100,confidence,matched_terms,lot_rank,explanation_short
35621604,Материалы расходные для дыроколов,Нож запасной Deli металлический для дырокола E0150 (2 штуки в упаковке),0321300001125000734_1,GOS2,2025-12-25,0321300001125000734,1,Щеточное оборудование для уборочной спецтехники.,Щеточное оборудование для уборочной спецтехники.,Подкат металлический для дисков щеточных,32.91.19.110,craft_punch,,unknown,0.13551506400108337,0.8371190428733826,0.2898679393529892,0.2857661545276642,0.28748890415430073,0.0023529411764705885,0.0,False,0.08,0.0,0.20984184533077133,28,low,металлический,1,"В лоте есть позиция ""Подкат металлический для дисков щеточных"". совпали слова: металлический. уверенность low. предупреждения: внутри лота слабый сигнал по типу товара"
35621604,Материалы расходные для дыроколов,Нож запасной Deli металлический для дырокола E0150 (2 штуки в упаковке),0373100037225001062_1,GOS2,2025-12-03,0373100037225001062,1,Поставка медицинских изделий,Поставка медицинских изделий,Нож,32.50.13.190,craft_punch,,unknown,0.09506508708000183,0.0,0.07415076792240143,0.24112048745155334,0.17099320524930953,0.0023529411764705885,0.0,False,0.08,0.0,0.09334614642578011,12,low,нож,2,"В лоте есть позиция ""Нож"". совпали слова: нож. уверенность low. предупреждения: внутри лота слабый сигнал по типу товара"
35621604,Материалы расходные для дыроколов,Нож запасной Deli металлический для дырокола E0150 (2 штуки в упаковке),0373100056625001694_1,GOS2,2025-12-25,0373100056625001694,1,Поставка товара (шкафы медицинские металлические),Поставка товара (шкафы медицинские металлические),Шкаф медицинский металлический для одежды,32.50.30.119,craft_punch,,unknown,0.1046234741806984,0.0,0.08160630986094475,0.1930258870124817,0.14622966460883619,0.0023529411764705885,0.0,False,0.08,0.0,0.06858260578530677,9,low,металлический,3,"В лоте есть позиция ""Шкаф медицинский металлический для одежды"". совпали слова: металлический. уверенность low. предупреждения: внутри лота слабый сигнал по типу товара"
35213112,USB-накопители твердотельные (флеш-драйвы)....,Флешка ADATA DashDrive UV150,0373200006225001699_1,GOS2,2025-12-02,0373200006225001699,1,Поставка устройств периферийных для компьютерного оборудования для нужд управы района Восточный города Москвы,Поставка устройств периферийных для компьютерного оборудования для нужд управы района Восточный города Москвы,USB-накопитель твердотельный (флеш-драйв),26.80.13.190,usb_flash,usb_flash,exact,0.11906391382217407,0.0,0.09286985278129578,0.15100738406181335,0.12658962092399598,0.009523809523809523,0.14,True,0.0,0.0,0.2761134304478055,37,medium,"usb, периферийное, устройство, флеш, флешка",3,"В лоте есть позиция ""USB-накопитель твердотельный (флеш-драйв)"". совпали слова: usb, периферийное, устройство, флеш. тип товара совпадает. уверенность medium"
1215368,Машины брошюровочные и переплетные,"Переплетная машина для пластиковой пружины BRAUBERG B8, пробивает 8 л., сшивает до 125 л.",B2112252058381_1,BUSINESS,2025-12-21,B2112252058381,1,Головка внутришлифовальная ВШГ 22-125-500А,Головка внутришлифовальная ВШГ 22-125-500А,Головка внутришлифовальная ВШГ 22-125-500А,28.41.40.000,binding_machine,,unknown,0.08390889316797256,0.852286696434021,0.25295200988650324,0.09370970726013184,0.16059147436320784,0.0011764705882352942,0.0,False,0.08,0.0,0.08176794495144314,11,low,125,1,"В лоте есть позиция ""Головка внутришлифовальная ВШГ 22-125-500А"". совпали слова: 125. уверенность low. предупреждения: внутри лота слабый сигнал по типу товара"
1215368,Машины брошюровочные и переплетные,"Переплетная машина для пластиковой пружины BRAUBERG B8, пробивает 8 л., сшивает до 125 л.",0873500002325000741_1,GOS2,2025-12-02,0873500002325000741,1,Поставка канцелярских товаров для нужд управы Филимонковского района города Москвы,Поставка канцелярских товаров для нужд управы Филимонковского района города Москвы,Пружина для переплета пластмассовая,22.29.25.000,binding_machine,,unknown,0.06551432609558105,0.0,0.051101174354553226,0.09268827736377716,0.0752216940999031,0.004705882352941177,0.0,True,0.0,0.0,0.07992757645284428,11,low,"листов, переплета, пластиковая, пружина",2,"В лоте есть позиция ""Пружина для переплета пластмассовая"". совпали слова: листов, переплета, пластиковая, пружина. уверенность low"
1215368,Машины брошюровочные и переплетные,"Переплетная машина для пластиковой пружины BRAUBERG B8, пробивает 8 л., сшивает до 125 л.",0873500002325000854_1,GOS2,2025-12-08,0873500002325000854,1,Поставка ледорезов для нужд ГБУ «Жилищник района Коммунарка»,Поставка ледорезов для нужд ГБУ «Жилищник района Коммунарка»,Машина для подрезки льда,28.99.39.190,binding_machine,,unknown,0.11421394348144531,0.0,0.08908687591552734,0.20318299531936646,0.15526262516975403,0.0011764705882352942,0.0,False,0.08,0.0,0.07643909575798934,10,low,машина,3,"В лоте есть позиция ""Машина для подрезки льда"". совпали слова: машина. уверенность low. предупреждения: внутри лота слабый сигнал по типу товара"
'''
print(BUYER_OUTPUT_EXAMPLE[:3000])

# %% [markdown]
# ## Ключевые выходные поля

# %%
OUTPUT_COLUMNS = [
    'seller_id',
    'seller_category',
    'seller_name',
    'lot_rank',
    'pn_lot',
    'lot_subject',
    'matched_unit_name',
    'confidence',
    'score_100',
    'matched_terms',
    'explanation_short',
]
OUTPUT_COLUMNS
